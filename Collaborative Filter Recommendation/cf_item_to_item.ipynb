# %%
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
from sklearn import tree

# %%
ratings = pd.read_csv("dataset/user_ratings_matrix_small.csv")
ratings
# Out:
#      users  Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# 0    user1                 0               2                        5
# 1    user2                 0               5                        1
# 2    user3                 0               1                        5
# 3    user4                 2               3                        1
# 4    user5                 3               3                        1
# 5    user6                 4               0                        5
# 6    user7                 3               1                        4
# 7    user8                 3               4                        4
# 8    user9                 0               5                        0
# 9   user10                 1               0                        1
# 10  user11                 3               3                        1
# 11  user12                 1               5                        3
# ...

# %%
ratings= ratings.set_index('users')

# %%
x = ratings[:]
print(x.head)
# Out:
# <bound method NDFrame.head of      users  Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# 0    user1                 0               2                        5
# 1    user2                 0               5                        1
# 2    user3                 0               1                        5
# 3    user4                 2               3                        1
# 4    user5                 3               3                        1
# 5    user6                 4               0                        5
# 6    user7                 3               1                        4
# 7    user8                 3               4                        4
# 8    user9                 0               5                        0
# 9   user10                 1               0                        1
# 10  user11                 3               3                        1
# 11  user12                 1               5                        3
# ...

# %%
ratings = ratings.set_index('users')
ratings.style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_f47ec_row0_col0,#T_f47ec_row0_col4,#T_f47ec_row0_col5,#T_f47ec_row1_col0,#T_f47ec_row1_col4,#T_f47ec_row2_col0,#T_f47ec_row2_col4,#T_f47ec_row2_col5,#T_f47ec_row3_col3,#T_f47ec_row5_col1,#T_f47ec_row5_col4,#T_f47ec_row7_col3,#T_f47ec_row8_col0,#T_f47ec_row8_col2,#T_f47ec_row9_col1,#T_f47ec_row14_col1,#T_f47ec_row16_col3,#T_f47ec_row18_col1,#T_f47ec_row18_col3,#T_f47ec_row18_col4,#T_f47ec_row18_col5,#T_f47ec_row20_col1,#T_f47ec_row21_col3,#T_f47ec_row21_col4,#T_f47ec_row22_col5,#T_f47ec_row23_col0,#T_f47ec_row24_col5,#T_f47ec_row25_col3,#T_f47ec_row26_col5,#T_f47ec_row27_col1,#T_f47ec_row29_col2{
#             background-color:  #440154;
#             color:  #f1f1f1;
# ...

# %%
x = ratings[:]
y = ratings[:]
treeclf = DecisionTreeClassifier(max_depth=10)
model = treeclf.fit(x,y)

# %%
img_rep = plt.figure(figsize = (25, 20))
_ = tree.plot_tree(treeclf, filled = True)

# %%
img_rep.savefig("decision_tree_item_to_item.png")

# %%
treeclf.predict_proba()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-5849c5c30d32> in <module>
# ----> 1 treeclf.predict_proba([5,5],[5,5])
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\tree\_classes.py in predict_proba(self, X, check_input)
#     928         """
#     929         check_is_fitted(self)
# --> 930         X = self._validate_X_predict(X, check_input)
#     931         proba = self.tree_.predict(X)
#     932
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     400         """Validate the training data on predict (probabilities)."""
#     401         if check_input:
# --> 402             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
#     403                                     reset=False)
# ...
